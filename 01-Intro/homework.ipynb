# %% [markdown]
# ## Homework

# %% [markdown]
# #### Q1. Pandas version

# %%
import pandas as pd
import numpy as np
import urllib.request

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
url = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv"
urllib.request.urlretrieve(url, "car_fuel_efficiency.csv")
# Out:
# ('car_fuel_efficiency.csv', <http.client.HTTPMessage at 0x1f549758190>)

# %%
df = pd.read_csv("car_fuel_efficiency.csv")

# %% [markdown]
# #### Q2. Records count

# %%
df.shape[0]
# Out:
# 9704

# %% [markdown]
# #### Q3. Fuel types

# %%
df['fuel_type'].nunique()
# Out:
# 2

# %% [markdown]
# #### Q4. Missing values

# %%
int((df.isnull().sum() > 0).sum())
# Out:
# 4

# %% [markdown]
# #### Q5. Max fuel efficiency

# %%
df[df.origin == 'Asia'].fuel_efficiency_mpg.max()
# Out:
# np.float64(23.759122836520497)

# %% [markdown]
# #### Q6. Median value of horsepower

# %%
df['horsepower'].median()
# Out:
# np.float64(149.0)

# %%
df['horsepower'].mode()
# Out:
# 0    152.0
# Name: horsepower, dtype: float64

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mode()[0])

# %%
df['horsepower'].median()
# Out:
# np.float64(152.0)

# %% [markdown]
# #### Q7. Sum of weights

# %%
X = df[df['origin'] == 'Asia'][['vehicle_weight', 'model_year']][:7].values

# %%
X
# Out:
# array([[2714.21930965, 2016.        ],
#        [2783.86897424, 2010.        ],
#        [3582.68736772, 2007.        ],
#        [2231.8081416 , 2011.        ],
#        [2659.43145076, 2016.        ],
#        [2844.22753389, 2014.        ],
#        [3761.99403819, 2019.        ]])

# %%
X.shape
# Out:
# (7, 2)

# %%
X_T = X.T

# %%
X_T
# Out:
# array([[2714.21930965, 2783.86897424, 3582.68736772, 2231.8081416 ,
#         2659.43145076, 2844.22753389, 3761.99403819],
#        [2016.        , 2010.        , 2007.        , 2011.        ,
#         2016.        , 2014.        , 2019.        ]])

# %%
XTX = X_T.dot(X)

# %%
np.linalg.inv(XTX)
# Out:
# array([[ 5.71497081e-07, -8.34509443e-07],
#        [-8.34509443e-07,  1.25380877e-06]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
np.linalg.inv(XTX).dot(X_T).dot(y).sum()
# Out:
# np.float64(0.5187709081074016)
